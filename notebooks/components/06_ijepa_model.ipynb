# %%
from functools import partial

import jax
from jax import numpy as jnp
import numpy as np
import einops

import equinox as eqx
from equinox.nn import Linear

from typing import Optional
from jaxtyping import Float, Array, PRNGKeyArray

import matplotlib.pyplot as plt

from jepax.data import build_dataset
from jepax.model.transformer import PositionalEncoding2D
from jepax.model.masker import IJEPAMasker, patchify, unpatchify, visualize_mask
from jepax.model.ijepa import IJEPA, IJEPAEncoder, IJEPAPredictor

dataloader, _, _, _ = build_dataset("CIFAR10", data_dir="~/data")
x, y = next(iter(dataloader))

show_mask = lambda x, mask: visualize_mask(x, mask, 2, 16)
# Out:
# /Users/anton/source/jepax/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)

# %%
x_in = x[-2]
plt.imshow(x_in)

# %% [markdown]
# ## Full Model

# %%
key = jax.random.PRNGKey(0)
key_e, key_p, key_m = jax.random.split(key, 3)
M = 4

masker = IJEPAMasker(32, 32, 2, ctx_scale=0.8, ctx_aspect=1.0, pred_scale=0.2, pred_aspect=(0.9, 1.2))

#@partial(jax.jit, static_argnums=(1,2))
def create_mask(key, M, flatten):
    return masker(key, M, flatten=flatten)

mask_ctx, mask_pred = create_mask(key_m, M, True)

encoder = IJEPAEncoder(
    key=key_e,
    num_channels=3,
    patch_size=2,
    dim=64,
    num_head=4,
    num_layers=1,
    img_size=32
)

predictor = IJEPAPredictor(
    key=key_p,
    latent_dim=32,
    grid_size=16,
    dim=64,
    num_head=2,
    num_layers=1
)

model = IJEPA(encoder, predictor)
#model = eqx.filter_jit(model)
# Out:
# 0.2
# /Users/anton/source/jepax/jepax/model/transformer.py:227: UserWarning: A JAX array is being set as static! This can result in unexpected behavior and is usually a mistake to do.
#   self.pe = PositionalEncoding2D(
# /Users/anton/source/jepax/jepax/model/transformer.py:223: UserWarning: A JAX array is being set as static! This can result in unexpected behavior and is usually a mistake to do.
#   self.pe = PositionalEncoding(dim=dim, seq_len=seq_len)
# /Users/anton/source/jepax/jepax/model/ijepa.py:250: UserWarning: A JAX array is being set as static! This can result in unexpected behavior and is usually a mistake to do.
#   self.pe = PositionalEncoding2D(dim=latent_dim, seq_len=seq_len, grid_size=grid_size)

# %%
mask_enc = ~(~mask_ctx | jnp.any(mask_pred, axis=0))
z, z_full, z_pred, mask_idx = model(key_e, x_in, mask_enc, mask_pred, num_pad=64)

# %%
target = z_full[mask_idx][mask_idx > 0]
target.shape
# Out:
# (36, 64)

# %%
pred = z_pred[mask_idx > 0]
pred.shape
# Out:
# (36, 64)

# %%
def loss_ijepa(model, x, mask_enc, mask_pred, num_pad=64):
    _, z_full, z_pred, mask_idx = model(key_e, x, mask_enc, mask_pred, num_pad=num_pad)

    target = z_full[mask_idx][mask_idx > 0]
    pred = z_pred[mask_idx > 0]

    return jnp.mean(jnp.sum((target - pred)**2, axis=-1), axis=0)

loss = loss_ijepa(model, x_in, mask_enc, mask_pred)
loss
# Out:
# Array(76.25415, dtype=float32)

# %%
encoder_ema = model.encoder
encoder_ema
# Out:
# IJEPAEncoder(
#   embed=PatchEmbedding(
#     linear=Linear(
#       weight=f32[64,12],
#       bias=f32[64],
#       in_features=12,
#       out_features=64,
#       use_bias=True
#     ),
#     patch_size=weak_f32[]
#   ),
#   transformer=Transformer(
#     blocks=[
#       TransformerBlock(
#         attn=Attention(
#           qkv_proj=Linear(
#             weight=f32[192,64],
#             bias=f32[192],
#             in_features=64,
#             out_features=192,
#             use_bias=True
#           ),
#           out_proj=Linear(
#             weight=f32[64,64],
#             bias=f32[64],
#             in_features=64,
#             out_features=64,
#             use_bias=True
#           ),
#           num_head=weak_f32[],
#           dim=weak_f32[],
#           causal=weak_f32[]
#         ),
#         ff=FeedForward(
#           linear1=Linear(
#             weight=f32[192,64],
#             bias=f32[192],
#             in_features=64,
#             out_features=192,
#             use_bias=True
#           ),
#           linear2=Linear(
#             weight=f32[64,192],
#             bias=f32[64],
#             in_features=192,
#             out_features=64,
#             use_bias=True
#           ),
#           norm=LayerNorm(
#             shape=(192,),
#             eps=1e-05,
#             use_weight=True,
#             use_bias=True,
#             weight=f32[192],
#             bias=f32[192]
#           )
#         ),
#         ln1=LayerNorm(
#           shape=(64,),
#           eps=1e-05,
#           use_weight=True,
#           use_bias=True,
#           weight=f32[64],
#           bias=f32[64]
#         ),
#         ln2=LayerNorm(
#           shape=(64,),
#           eps=1e-05,
#           use_weight=True,
#           use_bias=True,
#           weight=f32[64],
#           bias=f32[64]
#         ),
#         dropout=Dropout(p=weak_f32[], inference=weak_f32[])
#       )
#     ],
#     pe=PositionalEncoding2D(
#       pe=f64[2048,32](numpy), dim=64, grid=i64[2,16,16](numpy)
#     )
#   ),
#   mask_token=f32[1,64]
# )

# %%
model = jax.tree.map(
    jnp.zeros_like,
    model,
    is_leaf=eqx.is_array
)

encoder_new = jax.tree.map(
    lambda x, y: 0.9 * x + 0.1 * y,
    encoder_ema, model.encoder
)

model = eqx.tree_at(lambda m: m.encoder, model, encoder_new)

# %%
model.encoder.embed.linear.weight
# Out:
# Array([[-0.16222247, -0.052077  , -0.02428444, -0.10728671,  0.0471386 ,
#         -0.05229732,  0.0617197 , -0.02437493, -0.0151395 , -0.07861741,
#         -0.11033145, -0.08021928],
#        [-0.02374261,  0.08485418,  0.109473  ,  0.02042971,  0.05846284,
#          0.08681019,  0.1012662 ,  0.13406995,  0.17308292,  0.14699744,
#          0.16651158, -0.02545354],
#        [-0.11287256,  0.14551403,  0.12375218,  0.00724137, -0.0134124 ,
#          0.1058787 , -0.15470552, -0.15371758,  0.08618359, -0.09398726,
#         -0.13703544, -0.03895251],
#        [ 0.02376875,  0.0045496 , -0.01289026,  0.10042687, -0.1278266 ,
#         -0.08780322,  0.14385086,  0.05681444,  0.14663199, -0.16387822,
#          0.17136756, -0.13810836],
#        [ 0.0914892 , -0.18024535,  0.15158516, -0.11712202,  0.12124101,
#         -0.04525219,  0.09061082, -0.11707824, -0.08014433, -0.06400737,
#         -0.09913391,  0.16989917],
#         -0.06014993,  0.1697861 ,  0.1560779 ,  0.01818061, -0.0627704 ,
#          0.16511065, -0.15916964],
#        [-0.14204487,  0.17070867, -0.13395263, -0.1077135 ,  0.09628892,
#          0.0454992 , -0.1044076 , -0.01056479,  0.09971954, -0.11666362,
#         -0.06212204, -0.08112323],
#        [ 0.11941899, -0.06245331, -0.07327933, -0.15305533, -0.08364495,
#         -0.08629107, -0.11404998,  0.0298702 , -0.0094288 , -0.05678889,
#         -0.10650087,  0.15107463],
#        [ 0.16171375, -0.11533107, -0.10092675,  0.13181356, -0.15287134,
#         -0.10513962,  0.00545946, -0.08523405, -0.08909523,  0.17409195,
#          0.00804705,  0.01474321],
#        [ 0.06278589,  0.17827445,  0.02711729,  0.181627  ,  0.01746871,
#          0.0446797 ,  0.01381935,  0.11314563, -0.08470354, -0.04600554,
#         -0.12896062, -0.02634985],
#        [ 0.00338222,  0.066397  ,  0.17216972,  0.08563923,  0.00962906,
#         -0.13142179,  0.09244055, -0.078693  ,  0.18138881,  0.06640545,
#         -0.09842753,  0.18592606],
#        [-0.13233666, -0.02394247, -0.10662585,  0.06093691,  0.07512713,
#         -0.00074495, -0.1127509 ,  0.1369115 , -0.18244419,  0.08181592,
#         -0.17553544,  0.15805356],
#        [-0.043877  , -0.00968366, -0.07443299, -0.15968685, -0.12792477,
#          0.14652638,  0.18364103,  0.00410752,  0.02694804, -0.18792526,
#         -0.00599885, -0.04753408],
#        [ 0.06934164,  0.09972532, -0.07729857, -0.06855872, -0.14817712,
#          0.16526188,  0.12456759,  0.10554973,  0.12272815,  0.01264267,
#          0.13775878, -0.07776839],
#        [-0.13105357,  0.02774446,  0.06971347, -0.00541538, -0.17806186,
#         -0.15738031,  0.10939679, -0.09558145, -0.05504373, -0.02383852,
#         -0.18116365, -0.14402936],
#        [-0.16471177,  0.12633851,  0.18199304, -0.10157078,  0.07808131,
#         -0.04385112,  0.16757569,  0.15923765, -0.11520866,  0.15904129,
#         -0.04224573, -0.09866329],
#        [ 0.09929626, -0.13022372,  0.12599485, -0.08732118, -0.05243866,
#          0.00139578, -0.13775209,  0.14636657,  0.10404913,  0.13866682,
#         -0.04647245, -0.01771202],
#        [ 0.18664859,  0.04216471,  0.13549982,  0.02917872,  0.09100381,
#          0.15594015,  0.11619179,  0.05911296, -0.15632528,  0.14442317,
#          0.13701296,  0.129447  ],
#        [-0.00718782, -0.14900932,  0.08280373, -0.03754657,  0.04452689,
#          0.04176291,  0.05829644,  0.06830039,  0.18703601,  0.09642958,
#         -0.00459819, -0.11127602],
#        [-0.03876263, -0.1771579 ,  0.16559562, -0.1874107 , -0.14717379,
#          0.07782333,  0.00728761,  0.14922848, -0.14277826,  0.1173786 ,
#          0.06245598, -0.05150997],
#        [ 0.09892678, -0.14632404, -0.05326479, -0.00223881,  0.11935513,
#         -0.1036998 ,  0.13354735, -0.1624727 , -0.15067229,  0.1112719 ,
#          0.15181822,  0.1537557 ],
#        [-0.12784377, -0.05131647,  0.18496725, -0.1362398 , -0.00871225,
#         -0.10301284, -0.15184121, -0.06073231, -0.03304813, -0.08606709,
#         -0.11398829, -0.09099825],
#        [ 0.05720465,  0.10851267, -0.074099  ,  0.03234279,  0.17952321,
#         -0.15142757, -0.12140667, -0.0427097 , -0.16211425,  0.10607278,
#         -0.0073465 ,  0.10147211],
#        [ 0.0275772 , -0.0410041 ,  0.08396018,  0.00455041,  0.10586162,
#         -0.08787497, -0.01489895,  0.14251779,  0.06732104,  0.06896179,
#          0.0709625 ,  0.12352908],
#        [-0.02368201,  0.1624107 , -0.07151408, -0.16326901, -0.03987632,
#          0.0673577 , -0.04747814, -0.14542949,  0.11880422, -0.11199626,
#         -0.17475529, -0.13041858],
#        [ 0.07704696, -0.07393089, -0.01995151,  0.11545858,  0.18515263,
#          0.04907857, -0.04762087, -0.00257568,  0.0259681 , -0.02044935,
#         -0.13914159,  0.04526668],
#        [-0.15594546, -0.07532406,  0.06003138,  0.06399243, -0.03950821,
#         -0.14557846, -0.03396738,  0.00827211,  0.11186572,  0.14559525,
#         -0.13083926, -0.10520212],
#        [-0.04797684,  0.04406282,  0.12471704, -0.12765212, -0.09573815,
#         -0.10169156, -0.03081235,  0.0024095 ,  0.06393556, -0.02988153,
#         -0.05460589,  0.02007248],
#        [-0.10650036, -0.17363842,  0.05438459,  0.16281417, -0.11060485,
#          0.17647961, -0.15413484, -0.15138964,  0.1529282 ,  0.17650044,
#         -0.01808212, -0.16130446],
#        [ 0.09306579, -0.12082547, -0.13737527, -0.07439001, -0.0703737 ,
#          0.02488412,  0.02079119, -0.03743155, -0.08633229,  0.07658885,
#         -0.15254736, -0.15174669],
#        [-0.1336545 ,  0.15887037, -0.03464147,  0.07419647, -0.08397355,
#         -0.14640431, -0.13697335, -0.11878707,  0.14288013, -0.01916732,
#          0.05805797, -0.12540023],
#        [ 0.0940997 ,  0.08284482, -0.04375178,  0.16542253,  0.08285935,
#          0.02455949,  0.11262   ,  0.1428125 , -0.00026696,  0.1128377 ,
#         -0.18168508, -0.1171973 ],
#        [-0.0641716 ,  0.02912277,  0.14678828, -0.05512371, -0.1841069 ,
#          0.06170435,  0.16791245,  0.06220143, -0.16640884, -0.03805322,
#          0.03858146, -0.01259494],
#        [-0.09437885, -0.05594306, -0.09634849, -0.1818326 ,  0.06915926,
#         -0.1849561 ,  0.0662889 , -0.06500212, -0.15829855,  0.08356362,
#         -0.08512188,  0.01995936],
#        [ 0.12035743,  0.06706613, -0.09679115, -0.00720466, -0.01117111,
#         -0.00664269,  0.15865801,  0.16114932,  0.0760309 , -0.06697057,
#          0.18687436,  0.02766079]], dtype=float32)

# %% [markdown]
# ## MSE
